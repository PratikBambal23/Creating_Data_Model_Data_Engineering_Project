# %%
import pandas as pd
import psycopg2

# %%
def create_database():
    # Creating connection with Postgres Server
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=admin")
    conn.set_session(autocommit=True)
    
    #Creating Cursor to execute SQL queries
    cur = conn.cursor()
    
    # Initialy droping DATABASE accounts if aleady created
    cur.execute("DROP DATABASE IF EXISTS account")    
    cur.execute("CREATE DATABASE account")
    
    # Closing the current connection
    conn.close()
    
    # Connecting to newly created Database Accounts
    conn = psycopg2.connect("host=localhost dbname=account user=postgres password=admin")
    cur = conn.cursor()
    
    return cur, conn

# %%
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
def create_tables(cur, conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %%
AccountsCountry = pd.read_csv(r"F:\Data Engineering Projects\Creating Data Model\Wealth Data\Wealth-AccountsCountry.csv")
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
AccountsCountry_Clean = AccountsCountry[['Code', 'Long Name', 'Short Name', 'Table Name', 'Currency Unit']]
AccountsCountry_Clean.head()
# Out:
#   Code                  Long Name Short Name Table Name      Currency Unit
# 0  ALB        Republic of Albania    Albania    Albania       Albanian lek
# 1  ARG         Argentine Republic  Argentina  Argentina     Argentine peso
# 2  ARM        Republic of Armenia    Armenia    Armenia      Armenian dram
# 3  AUS  Commonwealth of Australia  Australia  Australia  Australian dollar
# 4  AUT        Republic of Austria    Austria    Austria               Euro

# %%
AccountsData = pd.read_csv(r"F:\Data Engineering Projects\Creating Data Model\Wealth Data\Wealth-AccountData.csv")
AccountsData.head()
# Out:
#   Country Name Country Code
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB

# %%
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code'], dtype='object')

# %%
AccountsData_Clean = AccountsData[['Country Name', 'Country Code']]
AccountsData_Clean.head()
# Out:
#   Country Name Country Code
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB

# %%
AccountSeries = pd.read_csv(r"F:\Data Engineering Projects\Creating Data Model\Wealth Data\Wealth-AccountSeries.csv")
AccountSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
AccountSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountSeries_Clean = AccountSeries[['Indicator Name', 'Long definition', 'Topic']]
AccountSeries_Clean.head()
# Out:
#                                       Indicator Name  \
# 0                  Human capital (constant 2018 US$)
# 1       Human capital per capita (constant 2018 US$)
# 2  Human capital per capita, employed female (con...
# 3  Human capital per capita, employed male (const...
# 4  Human capital per capita, female (constant 201...
#
#                                      Long definition          Topic
# 0  Human capital is computed as the present value...  Human capital
# 1  Human capital is computed as the present value...  Human capital
# 2  Human capital is computed as the present value...  Human capital
# 3  Human capital is computed as the present value...  Human capital
# 4  Human capital is computed as the present value...  Human capital

# %%
cur, conn = create_database()

# %%
songplay_table_create = (""" CREATE TABLE IF NOT EXISTS accountscountry(
country_code VARCHAR,
short_name VARCHAR,
table_name VARCHAR,
long_name VARCHAR,
currency_unit VARCHAR 
)""")

# %%
cur.execute(songplay_table_create)
conn.commit()

# %%
accounts_data_table_create = (""" CREATE TABLE IF NOT EXISTS accountsdata(
country_code VARCHAR,
country_name VARCHAR
)""")

# %%
cur.execute(accounts_data_table_create)
conn.commit()

# %%
accountsseries_data_table_create = (""" CREATE TABLE IF NOT EXISTS accountsseries(
topic VARCHAR,
indicator_name VARCHAR,
short_defination VARCHAR
)""")

# %%
cur.execute(accountsseries_data_table_create)
conn.commit()

# %% [markdown]
# ### Inserting Data into the tables

# %%
# Insert data into accountsCountry Table

accountscountry_data_table_insert = (""" INSERT INTO accountscountry(
country_code ,
short_name ,
table_name ,
long_name ,
currency_unit
)
VALUES(%s, %s, %s, %s, %s)""")

# %%
for i, row in AccountsCountry_Clean.iterrows():
    cur.execute(accountscountry_data_table_insert, list(row))
#     print(list(row))

# %%
conn.commit()

# %%
accountsdata_data_table_insert = (""" INSERT INTO accountsdata(
country_code ,
country_name
)
VALUES(%s, %s)""")

# %%
for i, row in AccountsData_Clean.iterrows():
    cur.execute(accountsdata_data_table_insert, list(row))
#     print(list(row))

# %%
accountsseries_data_table_insert = (""" INSERT INTO accountsseries(
topic ,
indicator_name ,
short_defination 
)
VALUES(%s, %s, %s)""")

# %%
for i, row in AccountSeries_Clean.iterrows():
    cur.execute(accountsseries_data_table_insert, list(row))
#     print(list(row))

# %%
conn.commit()

# %%
conn.close()
